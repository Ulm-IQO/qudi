# %%
remotenewfocuslaser.output_disable()

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
remotenewfocuslaser.output_enable()

# %%
remotenewfocuslaser.set_power(0.1)

# %%
laserscanner.goto_voltage(0.5)

# %%
nitrigger_logic.simple_off(channel='/Dev1/Port0/Line5')
# Out:
# True

# %%
y=laserscangui._voltscan_logic.plot_y

# %%
x=laserscangui._voltscan_logic.plot_x

# %%
plt.plot(x,y)

# %%
laserscanner._save_logic.get_path_for_module(module_name='LaserScanning')
# Out:
# 'C:/Data\\2021\\09\\20210924\\LaserScanning'

# %%
laserscanner.plot_x.shape
# Out:
# (1003,)

# %%
plt.show()

# %%
plt.plot(x,y)
plt.show()

# %%
import peakutils

# %%
from peakutils.plot import plot as pplot

# %%
import numpy as np

# %%
indexes = peakutils.indexes(y, thres=0.5, min_dist=120)
print(indexes)
print(x[indexes], y[indexes])
plt.figure(figsize=(10,6))
plt.plot(x, y,'-')
plt.plot(x[indexes], y[indexes],'or')
plt.title('First estimate')
plt.show()
# Out:
# [  8 136 300 421 586 742 864]
# [0.22087824 0.23493014 0.25293413 0.26621756 0.28433134 0.30145709
#  0.3148503 ] [ 9090.90909091 14545.45454545  9090.90909091 12727.27272727
#  11818.18181818  8181.81818182 10000.        ]

# %%
x.shape
# Out:
# (53,)

# %%
y.shape
# Out:
# (53,)

# %%
plt.plot(x,y,'o')

# %%
laserscangui.refresh_matrix()
